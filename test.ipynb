# %%
# %matplotlib inline
import matplotlib.pyplot
import numpy as np
import pandas as pd

# %%
dates = pd.date_range('20130101', periods=6)

df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>1.376526</td>
#       <td>-0.757359</td>
#       <td>1.599570</td>
#       <td>1.234904</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.938366</td>
#       <td>-1.926586</td>
#       <td>0.208308</td>
#       <td>0.254591</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>-0.268924</td>
#       <td>-0.784853</td>
#       <td>-2.039667</td>
#       <td>-1.041315</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>-0.186373</td>
#       <td>0.926975</td>
#       <td>2.381605</td>
#       <td>0.416818</td>
#     </tr>
#     <tr>
#       <th>2013-01-05</th>
#       <td>0.731254</td>
#       <td>-2.115894</td>
#       <td>0.100716</td>
#       <td>0.465533</td>
#     </tr>
#     <tr>
#       <th>2013-01-06</th>
#       <td>-0.796448</td>
#       <td>0.065921</td>
#       <td>0.026911</td>
#       <td>-1.446001</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.A
# Out:
# 2013-01-01    1.376526
# 2013-01-02    0.938366
# 2013-01-03   -0.268924
# 2013-01-04   -0.186373
# 2013-01-05    0.731254
# 2013-01-06   -0.796448
# Freq: D, Name: A, dtype: float64

# %%
df.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>6.000000</td>
#       <td>6.000000</td>
#       <td>6.000000</td>
#       <td>6.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>0.299067</td>
#       <td>-0.765299</td>
#       <td>0.379574</td>
#       <td>-0.019245</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.838430</td>
#       <td>1.159988</td>
#       <td>1.521888</td>
#       <td>1.015214</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>-0.796448</td>
#       <td>-2.115894</td>
#       <td>-2.039667</td>
#       <td>-1.446001</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>-0.248286</td>
#       <td>-1.641153</td>
#       <td>0.045363</td>
#       <td>-0.717339</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>0.272440</td>
#       <td>-0.771106</td>
#       <td>0.154512</td>
#       <td>0.335705</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>0.886588</td>
#       <td>-0.139899</td>
#       <td>1.251754</td>
#       <td>0.453355</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>1.376526</td>
#       <td>0.926975</td>
#       <td>2.381605</td>
#       <td>1.234904</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
list(df.columns)+['E']
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>1.376526</td>
#       <td>-0.757359</td>
#       <td>1.599570</td>
#       <td>1.234904</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.938366</td>
#       <td>-1.926586</td>
#       <td>0.208308</td>
#       <td>0.254591</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>-0.268924</td>
#       <td>-0.784853</td>
#       <td>-2.039667</td>
#       <td>-1.041315</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>-0.186373</td>
#       <td>0.926975</td>
#       <td>2.381605</td>
#       <td>0.416818</td>
#     </tr>
#     <tr>
#       <th>2013-01-05</th>
#       <td>0.731254</td>
#       <td>-2.115894</td>
#       <td>0.100716</td>
#       <td>0.465533</td>
#     </tr>
#     <tr>
#       <th>2013-01-06</th>
#       <td>-0.796448</td>
#       <td>0.065921</td>
#       <td>0.026911</td>
#       <td>-1.446001</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>1.376526</td>
#       <td>-0.757359</td>
#       <td>1.599570</td>
#       <td>1.234904</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.938366</td>
#       <td>-1.926586</td>
#       <td>0.208308</td>
#       <td>0.254591</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>-0.268924</td>
#       <td>-0.784853</td>
#       <td>-2.039667</td>
#       <td>-1.041315</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>-0.186373</td>
#       <td>0.926975</td>
#       <td>2.381605</td>
#       <td>0.416818</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df1.loc[dates[0]:dates[1],'E'] = 1

# %%
df1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>1.376526</td>
#       <td>-0.757359</td>
#       <td>1.599570</td>
#       <td>1.234904</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.938366</td>
#       <td>-1.926586</td>
#       <td>0.208308</td>
#       <td>0.254591</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>-0.268924</td>
#       <td>-0.784853</td>
#       <td>-2.039667</td>
#       <td>-1.041315</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>-0.186373</td>
#       <td>0.926975</td>
#       <td>2.381605</td>
#       <td>0.416818</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.mean()
# Out:
# A    0.299067
# B   -0.765299
# C    0.379574
# D   -0.019245
# dtype: float64

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>1.376526</td>
#       <td>-0.757359</td>
#       <td>1.599570</td>
#       <td>1.234904</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.938366</td>
#       <td>-1.926586</td>
#       <td>0.208308</td>
#       <td>0.254591</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>-0.268924</td>
#       <td>-0.784853</td>
#       <td>-2.039667</td>
#       <td>-1.041315</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>-0.186373</td>
#       <td>0.926975</td>
#       <td>2.381605</td>
#       <td>0.416818</td>
#     </tr>
#     <tr>
#       <th>2013-01-05</th>
#       <td>0.731254</td>
#       <td>-2.115894</td>
#       <td>0.100716</td>
#       <td>0.465533</td>
#     </tr>
#     <tr>
#       <th>2013-01-06</th>
#       <td>-0.796448</td>
#       <td>0.065921</td>
#       <td>0.026911</td>
#       <td>-1.446001</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.mean(1)
# Out:
# 2013-01-01    0.863410
# 2013-01-02   -0.131330
# 2013-01-03   -1.033690
# 2013-01-04    0.884756
# 2013-01-05   -0.204598
# 2013-01-06   -0.537404
# Freq: D, dtype: float64

# %%
pd.Series([1,3,5,np.nan,6,8], index=dates)
# Out:
# 2013-01-01    1.0
# 2013-01-02    3.0
# 2013-01-03    5.0
# 2013-01-04    NaN
# 2013-01-05    6.0
# 2013-01-06    8.0
# Freq: D, dtype: float64

# %%
s =pd.Series([1,3,5,np.nan,6,8], index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>1.376526</td>
#       <td>-0.757359</td>
#       <td>1.599570</td>
#       <td>1.234904</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.938366</td>
#       <td>-1.926586</td>
#       <td>0.208308</td>
#       <td>0.254591</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>-0.268924</td>
#       <td>-0.784853</td>
#       <td>-2.039667</td>
#       <td>-1.041315</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>-0.186373</td>
#       <td>0.926975</td>
#       <td>2.381605</td>
#       <td>0.416818</td>
#     </tr>
#     <tr>
#       <th>2013-01-05</th>
#       <td>0.731254</td>
#       <td>-2.115894</td>
#       <td>0.100716</td>
#       <td>0.465533</td>
#     </tr>
#     <tr>
#       <th>2013-01-06</th>
#       <td>-0.796448</td>
#       <td>0.065921</td>
#       <td>0.026911</td>
#       <td>-1.446001</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.sub(s,axis='index')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>-1.268924</td>
#       <td>-1.784853</td>
#       <td>-3.039667</td>
#       <td>-2.041315</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>-3.186373</td>
#       <td>-2.073025</td>
#       <td>-0.618395</td>
#       <td>-2.583182</td>
#     </tr>
#     <tr>
#       <th>2013-01-05</th>
#       <td>-4.268746</td>
#       <td>-7.115894</td>
#       <td>-4.899284</td>
#       <td>-4.534467</td>
#     </tr>
#     <tr>
#       <th>2013-01-06</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.apply(np.cumsum)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>1.376526</td>
#       <td>-0.757359</td>
#       <td>1.599570</td>
#       <td>1.234904</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>2.314892</td>
#       <td>-2.683945</td>
#       <td>1.807878</td>
#       <td>1.489496</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>2.045968</td>
#       <td>-3.468798</td>
#       <td>-0.231790</td>
#       <td>0.448180</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>1.859595</td>
#       <td>-2.541823</td>
#       <td>2.149816</td>
#       <td>0.864998</td>
#     </tr>
#     <tr>
#       <th>2013-01-05</th>
#       <td>2.590849</td>
#       <td>-4.657717</td>
#       <td>2.250532</td>
#       <td>1.330532</td>
#     </tr>
#     <tr>
#       <th>2013-01-06</th>
#       <td>1.794401</td>
#       <td>-4.591797</td>
#       <td>2.277443</td>
#       <td>-0.115469</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.apply(lambda x:x.max()-x.min())
# Out:
# A    2.172974
# B    3.042869
# C    4.421273
# D    2.680905
# dtype: float64

# %%
df.apply(lambda x:np.ptp(x))
# Out:
# A    2.172974
# B    3.042869
# C    4.421273
# D    2.680905
# dtype: float64

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s
# Out:
# 0    2
# 1    2
# 2    0
# 3    1
# 4    3
# 5    4
# 6    5
# 7    5
# 8    5
# 9    2
# dtype: int64

# %%
s.value_counts()
# Out:
# 5    3
# 2    3
# 4    1
# 3    1
# 1    1
# 0    1
# dtype: int64

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])

# %%
s
# Out:
# 0       A
# 1       B
# 2       C
# 3    Aaba
# 4    Baca
# 5     NaN
# 6    CABA
# 7     dog
# 8     cat
# dtype: object

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.735375</td>
#       <td>-2.057181</td>
#       <td>-0.056668</td>
#       <td>0.437569</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.977819</td>
#       <td>2.800418</td>
#       <td>1.209864</td>
#       <td>1.181994</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.673096</td>
#       <td>0.688642</td>
#       <td>1.437321</td>
#       <td>0.840238</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.118882</td>
#       <td>-1.333583</td>
#       <td>-0.221460</td>
#       <td>-1.517494</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-1.168175</td>
#       <td>1.442893</td>
#       <td>-0.979167</td>
#       <td>-0.221729</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2.951593</td>
#       <td>-0.205754</td>
#       <td>1.092387</td>
#       <td>0.230892</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.001396</td>
#       <td>0.823832</td>
#       <td>0.845838</td>
#       <td>-0.706175</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>-0.746220</td>
#       <td>-0.774318</td>
#       <td>0.338663</td>
#       <td>0.132110</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-0.981685</td>
#       <td>0.213225</td>
#       <td>-1.286617</td>
#       <td>-0.498105</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>-0.222332</td>
#       <td>0.068874</td>
#       <td>-0.143909</td>
#       <td>0.474771</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pieces = [df[:3], df[3:7], df[7:]]
pieces
# Out:
# [          0         1         2         3
#  0  0.735375 -2.057181 -0.056668  0.437569
#  1  0.977819  2.800418  1.209864  1.181994
#  2  0.673096  0.688642  1.437321  0.840238,
#            0         1         2         3
#  3  1.118882 -1.333583 -0.221460 -1.517494
#  4 -1.168175  1.442893 -0.979167 -0.221729
#  5  2.951593 -0.205754  1.092387  0.230892
#  6  0.001396  0.823832  0.845838 -0.706175,
#            0         1         2         3
#  7 -0.746220 -0.774318  0.338663  0.132110
#  8 -0.981685  0.213225 -1.286617 -0.498105
#  9 -0.222332  0.068874 -0.143909  0.474771]

# %%
pd.concat(pieces,axis=0)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.735375</td>
#       <td>-2.057181</td>
#       <td>-0.056668</td>
#       <td>0.437569</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.977819</td>
#       <td>2.800418</td>
#       <td>1.209864</td>
#       <td>1.181994</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.673096</td>
#       <td>0.688642</td>
#       <td>1.437321</td>
#       <td>0.840238</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.118882</td>
#       <td>-1.333583</td>
#       <td>-0.221460</td>
#       <td>-1.517494</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-1.168175</td>
#       <td>1.442893</td>
#       <td>-0.979167</td>
#       <td>-0.221729</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2.951593</td>
#       <td>-0.205754</td>
#       <td>1.092387</td>
#       <td>0.230892</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.001396</td>
#       <td>0.823832</td>
#       <td>0.845838</td>
#       <td>-0.706175</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>-0.746220</td>
#       <td>-0.774318</td>
#       <td>0.338663</td>
#       <td>0.132110</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-0.981685</td>
#       <td>0.213225</td>
#       <td>-1.286617</td>
#       <td>-0.498105</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>-0.222332</td>
#       <td>0.068874</td>
#       <td>-0.143909</td>
#       <td>0.474771</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})
left
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>lval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>foo</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>bar</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})

# %%
right
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>rval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>foo</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>bar</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pd.merge(left, right, on='key')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>lval</th>
#       <th>rval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>foo</td>
#       <td>1</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>bar</td>
#       <td>2</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A','B','C','D'])
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2.128509</td>
#       <td>-1.098260</td>
#       <td>0.092361</td>
#       <td>-0.009853</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.990309</td>
#       <td>0.533289</td>
#       <td>-0.484933</td>
#       <td>-0.782560</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.002888</td>
#       <td>-0.891284</td>
#       <td>-0.756940</td>
#       <td>1.212921</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.780222</td>
#       <td>-0.357034</td>
#       <td>0.462431</td>
#       <td>-0.326853</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-2.296396</td>
#       <td>-0.043686</td>
#       <td>-1.920011</td>
#       <td>1.346172</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>-2.063417</td>
#       <td>0.819544</td>
#       <td>0.274973</td>
#       <td>-0.948209</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.806155</td>
#       <td>1.166822</td>
#       <td>0.561121</td>
#       <td>-0.274622</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>-1.359909</td>
#       <td>-0.650576</td>
#       <td>1.628103</td>
#       <td>0.707186</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
s = df.iloc[3]

# %%
df.append(s, ignore_index=True)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2.128509</td>
#       <td>-1.098260</td>
#       <td>0.092361</td>
#       <td>-0.009853</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.990309</td>
#       <td>0.533289</td>
#       <td>-0.484933</td>
#       <td>-0.782560</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.002888</td>
#       <td>-0.891284</td>
#       <td>-0.756940</td>
#       <td>1.212921</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.780222</td>
#       <td>-0.357034</td>
#       <td>0.462431</td>
#       <td>-0.326853</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-2.296396</td>
#       <td>-0.043686</td>
#       <td>-1.920011</td>
#       <td>1.346172</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>-2.063417</td>
#       <td>0.819544</td>
#       <td>0.274973</td>
#       <td>-0.948209</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.806155</td>
#       <td>1.166822</td>
#       <td>0.561121</td>
#       <td>-0.274622</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>-1.359909</td>
#       <td>-0.650576</td>
#       <td>1.628103</td>
#       <td>0.707186</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-0.780222</td>
#       <td>-0.357034</td>
#       <td>0.462431</td>
#       <td>-0.326853</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
                         'foo', 'bar', 'foo', 'foo'],
                   'B': ['one', 'one', 'two', 'three',
                         'two', 'two', 'one', 'three'],
                   'C': np.random.randn(8),
                   'D': np.random.randn(8)})
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>foo</td>
#       <td>one</td>
#       <td>0.986671</td>
#       <td>1.613902</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>bar</td>
#       <td>one</td>
#       <td>1.357733</td>
#       <td>0.167369</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>foo</td>
#       <td>two</td>
#       <td>0.025099</td>
#       <td>-0.366012</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>bar</td>
#       <td>three</td>
#       <td>-0.620296</td>
#       <td>-0.494643</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>foo</td>
#       <td>two</td>
#       <td>1.100564</td>
#       <td>0.382273</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>bar</td>
#       <td>two</td>
#       <td>-0.205907</td>
#       <td>-0.321204</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>foo</td>
#       <td>one</td>
#       <td>-0.005792</td>
#       <td>-0.569647</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>foo</td>
#       <td>three</td>
#       <td>-0.325481</td>
#       <td>-0.162550</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.groupby('A').sum()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#     <tr>
#       <th>A</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>bar</th>
#       <td>0.53153</td>
#       <td>-0.648478</td>
#     </tr>
#     <tr>
#       <th>foo</th>
#       <td>1.78106</td>
#       <td>0.897966</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.groupby(['A','B']).sum()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#     <tr>
#       <th>A</th>
#       <th>B</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="3" valign="top">bar</th>
#       <th>one</th>
#       <td>1.357733</td>
#       <td>0.167369</td>
#     </tr>
#     <tr>
#       <th>three</th>
#       <td>-0.620296</td>
#       <td>-0.494643</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>-0.205907</td>
#       <td>-0.321204</td>
#     </tr>
#     <tr>
#       <th rowspan="3" valign="top">foo</th>
#       <th>one</th>
#       <td>0.980878</td>
#       <td>1.044255</td>
#     </tr>
#     <tr>
#       <th>three</th>
#       <td>-0.325481</td>
#       <td>-0.162550</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>1.125663</td>
#       <td>0.016261</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
                     'foo', 'foo', 'qux', 'qux'],
                    ['one', 'two', 'one', 'two',
                     'one', 'two', 'one', 'two']]))
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
index
# Out:
# MultiIndex(levels=[['bar', 'baz', 'foo', 'qux'], ['one', 'two']],
#            labels=[[0, 0, 1, 1, 2, 2, 3, 3], [0, 1, 0, 1, 0, 1, 0, 1]],
#            names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#     <tr>
#       <th>first</th>
#       <th>second</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">bar</th>
#       <th>one</th>
#       <td>-0.174211</td>
#       <td>0.499710</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>0.363625</td>
#       <td>-1.263227</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">baz</th>
#       <th>one</th>
#       <td>1.601704</td>
#       <td>-0.045521</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>1.059906</td>
#       <td>0.481303</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">foo</th>
#       <th>one</th>
#       <td>-0.707011</td>
#       <td>1.510596</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>0.213238</td>
#       <td>0.392746</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">qux</th>
#       <th>one</th>
#       <td>-0.326875</td>
#       <td>-0.209406</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>-0.575186</td>
#       <td>0.700776</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df2 = df[:4]
df2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#     <tr>
#       <th>first</th>
#       <th>second</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">bar</th>
#       <th>one</th>
#       <td>-0.174211</td>
#       <td>0.499710</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>0.363625</td>
#       <td>-1.263227</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">baz</th>
#       <th>one</th>
#       <td>1.601704</td>
#       <td>-0.045521</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>1.059906</td>
#       <td>0.481303</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A   -0.174211
#                B    0.499710
#        two     A    0.363625
#                B   -1.263227
# baz    one     A    1.601704
#                B   -0.045521
#        two     A    1.059906
#                B    0.481303
# dtype: float64

# %%
stacked.unstack()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#     <tr>
#       <th>first</th>
#       <th>second</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">bar</th>
#       <th>one</th>
#       <td>-0.174211</td>
#       <td>0.499710</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>0.363625</td>
#       <td>-1.263227</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">baz</th>
#       <th>one</th>
#       <td>1.601704</td>
#       <td>-0.045521</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>1.059906</td>
#       <td>0.481303</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
stacked.unstack(1)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>second</th>
#       <th>one</th>
#       <th>two</th>
#     </tr>
#     <tr>
#       <th>first</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">bar</th>
#       <th>A</th>
#       <td>-0.174211</td>
#       <td>0.363625</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>0.499710</td>
#       <td>-1.263227</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">baz</th>
#       <th>A</th>
#       <td>1.601704</td>
#       <td>1.059906</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>-0.045521</td>
#       <td>0.481303</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
stacked.unstack(0)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>first</th>
#       <th>bar</th>
#       <th>baz</th>
#     </tr>
#     <tr>
#       <th>second</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">one</th>
#       <th>A</th>
#       <td>-0.174211</td>
#       <td>1.601704</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>0.499710</td>
#       <td>-0.045521</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">two</th>
#       <th>A</th>
#       <td>0.363625</td>
#       <td>1.059906</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>-1.263227</td>
#       <td>0.481303</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df = pd.DataFrame({'A': ['one', 'one', 'two', 'three'] * 3,
                   'B': ['A', 'B', 'C'] * 4,
                   'C': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                   'D': np.random.randn(12),
                   'E': np.random.randn(12)})
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>one</td>
#       <td>A</td>
#       <td>foo</td>
#       <td>0.687348</td>
#       <td>3.108160</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>one</td>
#       <td>B</td>
#       <td>foo</td>
#       <td>0.570273</td>
#       <td>0.851215</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>two</td>
#       <td>C</td>
#       <td>foo</td>
#       <td>0.873763</td>
#       <td>1.300537</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>three</td>
#       <td>A</td>
#       <td>bar</td>
#       <td>1.805009</td>
#       <td>0.757742</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>one</td>
#       <td>B</td>
#       <td>bar</td>
#       <td>0.233200</td>
#       <td>0.470289</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>one</td>
#       <td>C</td>
#       <td>bar</td>
#       <td>0.332271</td>
#       <td>0.834042</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>two</td>
#       <td>A</td>
#       <td>foo</td>
#       <td>0.694370</td>
#       <td>0.623645</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>three</td>
#       <td>B</td>
#       <td>foo</td>
#       <td>1.118547</td>
#       <td>-0.002899</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>one</td>
#       <td>C</td>
#       <td>foo</td>
#       <td>-0.099413</td>
#       <td>-0.501483</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>one</td>
#       <td>A</td>
#       <td>bar</td>
#       <td>0.670661</td>
#       <td>-3.312082</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>two</td>
#       <td>B</td>
#       <td>bar</td>
#       <td>0.687049</td>
#       <td>-0.304557</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>three</td>
#       <td>C</td>
#       <td>bar</td>
#       <td>0.559760</td>
#       <td>0.587118</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>C</th>
#       <th>bar</th>
#       <th>foo</th>
#     </tr>
#     <tr>
#       <th>A</th>
#       <th>B</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="3" valign="top">one</th>
#       <th>A</th>
#       <td>0.670661</td>
#       <td>0.687348</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>0.233200</td>
#       <td>0.570273</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>0.332271</td>
#       <td>-0.099413</td>
#     </tr>
#     <tr>
#       <th rowspan="3" valign="top">three</th>
#       <th>A</th>
#       <td>1.805009</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>NaN</td>
#       <td>1.118547</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>0.559760</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th rowspan="3" valign="top">two</th>
#       <th>A</th>
#       <td>NaN</td>
#       <td>0.694370</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>0.687049</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>NaN</td>
#       <td>0.873763</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a', 'b', 'b', 'a', 'a', 'e']})
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>raw_grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>b</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>b</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>e</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df["grade"] = df["raw_grade"].astype("category")

# %%
df.dtypes
# Out:
# id              int64
# raw_grade      object
# grade        category
# dtype: object

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>raw_grade</th>
#       <th>grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>a</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>b</td>
#       <td>b</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>b</td>
#       <td>b</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>a</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>a</td>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>e</td>
#       <td>e</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>raw_grade</th>
#       <th>grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>a</td>
#       <td>very good</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>b</td>
#       <td>good</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>b</td>
#       <td>good</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>a</td>
#       <td>very good</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>a</td>
#       <td>very good</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>e</td>
#       <td>very bad</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-130-e0abf3c61dfa> in <module>()
#       3 ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
#       4 ts = ts.cumsum()
# ----> 5 ts.plot()
#       6 plt.show()
#
# /Users/ice/PycharmProjects/sklearn-study/venv/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2501                            colormap=colormap, table=table, yerr=yerr,
#    2502                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2503                            **kwds)
#    2504     __call__.__doc__ = plot_series.__doc__
#    2505
#
# /Users/ice/PycharmProjects/sklearn-study/venv/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    1925                  yerr=yerr, xerr=xerr,
#    1926                  label=label, secondary_y=secondary_y,
# -> 1927                  **kwds)
#    1928
#    1929
#
# /Users/ice/PycharmProjects/sklearn-study/venv/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1727         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1728
# -> 1729     plot_obj.generate()
#    1730     plot_obj.draw()
#    1731     return plot_obj.result
#
# /Users/ice/PycharmProjects/sklearn-study/venv/lib/python3.6/site-packages/pandas/plotting/_core.py in generate(self)
#     250         self._compute_plot_data()
#     251         self._setup_subplots()
# --> 252         self._make_plot()
#     253         self._add_table()
#     254         self._make_legend()
#
# /Users/ice/PycharmProjects/sklearn-study/venv/lib/python3.6/site-packages/pandas/plotting/_core.py in _make_plot(self)
#     975                              stacking_id=stacking_id,
#     976                              is_errorbar=is_errorbar,
# --> 977                              **kwds)
#     978             self._add_legend_handle(newlines[0], label, index=i)
#     979
#
# /Users/ice/PycharmProjects/sklearn-study/venv/lib/python3.6/site-packages/pandas/plotting/_core.py in _ts_plot(cls, ax, x, data, style, **kwds)
#    1016         lines = cls._plot(ax, data.index, data.values, style=style, **kwds)
#    1017         # set date formatter, locators and rescale limits
# -> 1018         format_dateaxis(ax, ax.freq, data.index)
#    1019         return lines
#    1020
#
# /Users/ice/PycharmProjects/sklearn-study/venv/lib/python3.6/site-packages/pandas/plotting/_timeseries.py in format_dateaxis(subplot, freq, index)
#     342         raise TypeError('index type not supported')
#     343
# --> 344     pylab.draw_if_interactive()
#
# /Users/ice/PycharmProjects/sklearn-study/venv/lib/python3.6/site-packages/IPython/utils/decorators.py in wrapper(*args, **kw)
#      41     def wrapper(*args,**kw):
#      42         wrapper.called = False
# ---> 43         out = func(*args,**kw)
#      44         wrapper.called = True
#      45         return out
#
# /Applications/PyCharm.app/Contents/helpers/pycharm_matplotlib_backend/backend_interagg.py in draw_if_interactive()
#      37         figManager = Gcf.get_active()
#      38         if figManager is not None:
# ---> 39             figManager.canvas.show()
#      40
#      41
#
# AttributeError: 'FigureCanvasAgg' object has no attribute 'show'

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
                  columns=['A', 'B', 'C', 'D'])
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2000-01-01</th>
#       <td>0.861361</td>
#       <td>-0.860496</td>
#       <td>0.306032</td>
#       <td>0.254095</td>
#     </tr>
#     <tr>
#       <th>2000-01-02</th>
#       <td>-1.576524</td>
#       <td>-1.430723</td>
#       <td>-0.698709</td>
#       <td>-1.501667</td>
#     </tr>
#     <tr>
#       <th>2000-01-03</th>
#       <td>0.243527</td>
#       <td>-1.458009</td>
#       <td>-0.045692</td>
#       <td>0.869343</td>
#     </tr>
#     <tr>
#       <th>2000-01-04</th>
#       <td>-0.650530</td>
#       <td>-1.233328</td>
#       <td>0.080672</td>
#       <td>-0.781874</td>
#     </tr>
#     <tr>
#       <th>2000-01-05</th>
#       <td>2.249793</td>
#       <td>-0.403457</td>
#       <td>-0.881101</td>
#       <td>-0.357498</td>
#     </tr>
#     <tr>
#       <th>2000-01-06</th>
#       <td>-0.600441</td>
#       <td>-0.384163</td>
#       <td>-1.457691</td>
#       <td>1.160414</td>
#     </tr>
#     <tr>
#       <th>2000-01-07</th>
#       <td>-0.483141</td>
#       <td>-2.102944</td>
#       <td>0.449824</td>
#       <td>2.612588</td>
#     </tr>
#     <tr>
#       <th>2000-01-08</th>
#       <td>1.449799</td>
#       <td>-0.599834</td>
#       <td>0.786053</td>
#       <td>-0.902184</td>
#     </tr>
#     <tr>
#       <th>2000-01-09</th>
#       <td>0.065514</td>
#       <td>1.353821</td>
#       <td>0.162613</td>
#       <td>-2.704765</td>
#     </tr>
#     <tr>
#       <th>2000-01-10</th>
#       <td>0.071751</td>
#       <td>-0.631942</td>
#       <td>0.569265</td>
#       <td>0.186126</td>
#     </tr>
#     <tr>
#       <th>2000-01-11</th>
#       <td>-1.055707</td>
#       <td>-0.751845</td>
#       <td>-0.934242</td>
#       <td>-0.325473</td>
#     </tr>
#     <tr>
#       <th>2000-01-12</th>
#       <td>-1.329748</td>
#       <td>-0.922894</td>
#       <td>0.814129</td>
#       <td>0.126222</td>
#     </tr>
#     <tr>
#       <th>2000-01-13</th>
#       <td>0.056352</td>
#       <td>-1.784591</td>
#       <td>-0.205267</td>
#       <td>-1.132587</td>
#     </tr>
#     <tr>
#       <th>2000-01-14</th>
#       <td>1.965608</td>
#       <td>1.389070</td>
#       <td>2.686568</td>
#       <td>-0.870856</td>
#     </tr>
#     <tr>
#       <th>2000-01-15</th>
#       <td>-0.219696</td>
#       <td>0.074873</td>
#       <td>0.460381</td>
#       <td>-1.229975</td>
#     </tr>
#     <tr>
#       <th>2000-01-16</th>
#       <td>-1.629673</td>
#       <td>0.754950</td>
#       <td>1.473003</td>
#       <td>0.110392</td>
#     </tr>
#     <tr>
#       <th>2000-01-17</th>
#       <td>-0.306545</td>
#       <td>0.332292</td>
#       <td>1.202218</td>
#       <td>-1.104971</td>
#     </tr>
#     <tr>
#       <th>2000-01-18</th>
#       <td>-0.326440</td>
#       <td>-0.173763</td>
#       <td>-0.494792</td>
#       <td>-1.215407</td>
#     </tr>
#     <tr>
#       <th>2000-01-19</th>
#       <td>0.349514</td>
#       <td>0.756202</td>
#       <td>-0.250523</td>
#       <td>1.055621</td>
#     </tr>
#     <tr>
#       <th>2000-01-20</th>
#       <td>-0.155109</td>
#       <td>-1.162779</td>
#       <td>0.153240</td>
#       <td>0.080929</td>
#     </tr>
#     <tr>
#       <th>2000-01-21</th>
#       <td>0.978927</td>
#       <td>-1.015235</td>
#       <td>1.244271</td>
#       <td>-0.646933</td>
#     </tr>
#     <tr>
#       <th>2000-01-22</th>
#       <td>0.377367</td>
#       <td>-0.155281</td>
#       <td>-0.155594</td>
#       <td>0.679391</td>
#     </tr>
#     <tr>
#       <th>2000-01-23</th>
#       <td>-0.354158</td>
#       <td>1.194871</td>
#       <td>-0.394550</td>
#       <td>-0.861124</td>
#     </tr>
#     <tr>
#       <th>2000-01-24</th>
#       <td>-0.870835</td>
#       <td>0.540655</td>
#       <td>-1.321747</td>
#       <td>0.389397</td>
#     </tr>
#     <tr>
#       <th>2000-01-25</th>
#       <td>1.199393</td>
#       <td>-0.864269</td>
#       <td>-1.333522</td>
#       <td>1.609983</td>
#     </tr>
#     <tr>
#       <th>2000-01-26</th>
#       <td>0.551580</td>
#       <td>1.404559</td>
#       <td>-0.400712</td>
#       <td>-0.343929</td>
#     </tr>
#     <tr>
#       <th>2000-01-27</th>
#       <td>0.370107</td>
#       <td>0.401662</td>
#       <td>0.343666</td>
#       <td>-0.281091</td>
#     </tr>
#     <tr>
#       <th>2000-01-28</th>
#       <td>1.306232</td>
#       <td>-1.718587</td>
#       <td>0.958216</td>
#       <td>-0.652447</td>
#     </tr>
#     <tr>
#       <th>2000-01-29</th>
#       <td>-0.476574</td>
#       <td>0.137788</td>
#       <td>0.114695</td>
#       <td>-0.441954</td>
#     </tr>
#     <tr>
#       <th>2000-01-30</th>
#       <td>1.717090</td>
#       <td>0.097945</td>
#       <td>-1.136285</td>
#       <td>0.871859</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>2002-08-28</th>
#       <td>0.427323</td>
#       <td>-0.283158</td>
#       <td>-0.261499</td>
#       <td>0.583930</td>
#     </tr>
#     <tr>
#       <th>2002-08-29</th>
#       <td>-2.660009</td>
#       <td>0.563760</td>
#       <td>-2.276312</td>
#       <td>-0.473642</td>
#     </tr>
#     <tr>
#       <th>2002-08-30</th>
#       <td>0.713638</td>
#       <td>0.467836</td>
#       <td>0.675206</td>
#       <td>0.894660</td>
#     </tr>
#     <tr>
#       <th>2002-08-31</th>
#       <td>-1.201692</td>
#       <td>0.440674</td>
#       <td>-0.318991</td>
#       <td>0.992078</td>
#     </tr>
#     <tr>
#       <th>2002-09-01</th>
#       <td>0.524065</td>
#       <td>-1.207002</td>
#       <td>1.189857</td>
#       <td>-0.651652</td>
#     </tr>
#     <tr>
#       <th>2002-09-02</th>
#       <td>0.220736</td>
#       <td>0.269342</td>
#       <td>2.078210</td>
#       <td>-0.371775</td>
#     </tr>
#     <tr>
#       <th>2002-09-03</th>
#       <td>-0.433754</td>
#       <td>-0.526361</td>
#       <td>1.222434</td>
#       <td>-0.101943</td>
#     </tr>
#     <tr>
#       <th>2002-09-04</th>
#       <td>1.228952</td>
#       <td>0.428599</td>
#       <td>-1.787087</td>
#       <td>-1.819275</td>
#     </tr>
#     <tr>
#       <th>2002-09-05</th>
#       <td>0.196383</td>
#       <td>-0.973609</td>
#       <td>0.025880</td>
#       <td>-0.313765</td>
#     </tr>
#     <tr>
#       <th>2002-09-06</th>
#       <td>-0.172169</td>
#       <td>-0.421494</td>
#       <td>1.263017</td>
#       <td>-0.390913</td>
#     </tr>
#     <tr>
#       <th>2002-09-07</th>
#       <td>-0.119420</td>
#       <td>1.262323</td>
#       <td>2.500195</td>
#       <td>1.472437</td>
#     </tr>
#     <tr>
#       <th>2002-09-08</th>
#       <td>-0.635690</td>
#       <td>-1.547969</td>
#       <td>-0.197595</td>
#       <td>0.042995</td>
#     </tr>
#     <tr>
#       <th>2002-09-09</th>
#       <td>1.431573</td>
#       <td>0.537248</td>
#       <td>-0.550638</td>
#       <td>2.130242</td>
#     </tr>
#     <tr>
#       <th>2002-09-10</th>
#       <td>-0.610767</td>
#       <td>0.830548</td>
#       <td>-0.782509</td>
#       <td>-1.106721</td>
#     </tr>
#     <tr>
#       <th>2002-09-11</th>
#       <td>0.894569</td>
#       <td>-0.018762</td>
#       <td>-0.698700</td>
#       <td>-0.182448</td>
#     </tr>
#     <tr>
#       <th>2002-09-12</th>
#       <td>1.251717</td>
#       <td>-0.238222</td>
#       <td>0.004556</td>
#       <td>0.913960</td>
#     </tr>
#     <tr>
#       <th>2002-09-13</th>
#       <td>0.694191</td>
#       <td>-0.949582</td>
#       <td>-1.052022</td>
#       <td>0.290428</td>
#     </tr>
#     <tr>
#       <th>2002-09-14</th>
#       <td>-0.052761</td>
#       <td>0.941473</td>
#       <td>-0.095642</td>
#       <td>1.504989</td>
#     </tr>
#     <tr>
#       <th>2002-09-15</th>
#       <td>-0.040203</td>
#       <td>-0.366724</td>
#       <td>1.236564</td>
#       <td>-1.620110</td>
#     </tr>
#     <tr>
#       <th>2002-09-16</th>
#       <td>0.056190</td>
#       <td>0.010045</td>
#       <td>-0.434831</td>
#       <td>0.267226</td>
#     </tr>
#     <tr>
#       <th>2002-09-17</th>
#       <td>0.673394</td>
#       <td>0.982102</td>
#       <td>-0.896439</td>
#       <td>0.604867</td>
#     </tr>
#     <tr>
#       <th>2002-09-18</th>
#       <td>-0.041637</td>
#       <td>-0.909368</td>
#       <td>0.698705</td>
#       <td>-0.224951</td>
#     </tr>
#     <tr>
#       <th>2002-09-19</th>
#       <td>-1.185131</td>
#       <td>0.749766</td>
#       <td>1.056700</td>
#       <td>-0.025403</td>
#     </tr>
#     <tr>
#       <th>2002-09-20</th>
#       <td>-0.745099</td>
#       <td>-1.323687</td>
#       <td>1.210367</td>
#       <td>1.357935</td>
#     </tr>
#     <tr>
#       <th>2002-09-21</th>
#       <td>-1.062654</td>
#       <td>-1.549531</td>
#       <td>0.260458</td>
#       <td>0.837211</td>
#     </tr>
#     <tr>
#       <th>2002-09-22</th>
#       <td>0.235988</td>
#       <td>0.651888</td>
#       <td>0.639168</td>
#       <td>1.480077</td>
#     </tr>
#     <tr>
#       <th>2002-09-23</th>
#       <td>-0.393317</td>
#       <td>0.182268</td>
#       <td>1.317013</td>
#       <td>2.220454</td>
#     </tr>
#     <tr>
#       <th>2002-09-24</th>
#       <td>-0.272032</td>
#       <td>0.837253</td>
#       <td>-1.336524</td>
#       <td>0.008257</td>
#     </tr>
#     <tr>
#       <th>2002-09-25</th>
#       <td>0.134736</td>
#       <td>1.437136</td>
#       <td>-0.352404</td>
#       <td>1.015669</td>
#     </tr>
#     <tr>
#       <th>2002-09-26</th>
#       <td>0.785989</td>
#       <td>0.445860</td>
#       <td>0.027425</td>
#       <td>-0.542598</td>
#     </tr>
#   </tbody>
# </table>
# <p>1000 rows × 4 columns</p>
# </div>

# %%
df = df.cumsum()

# %%
plt.figure()
df.plot()
plt.legend(loc='best')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-135-3ebec0112176> in <module>()
#       1 plt.figure()
# ----> 2 df.plot()
#       3 plt.legend(loc='best')
#
# /Users/ice/PycharmProjects/sklearn-study/venv/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2675                           fontsize=fontsize, colormap=colormap, table=table,
#    2676                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2677                           sort_columns=sort_columns, **kwds)
#    2678     __call__.__doc__ = plot_frame.__doc__
#    2679
#
# /Users/ice/PycharmProjects/sklearn-study/venv/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1900                  yerr=yerr, xerr=xerr,
#    1901                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1902                  **kwds)
#    1903
#    1904
#
# /Users/ice/PycharmProjects/sklearn-study/venv/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1727         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1728
# -> 1729     plot_obj.generate()
#    1730     plot_obj.draw()
#    1731     return plot_obj.result
#
# /Users/ice/PycharmProjects/sklearn-study/venv/lib/python3.6/site-packages/pandas/plotting/_core.py in generate(self)
#     250         self._compute_plot_data()
#     251         self._setup_subplots()
# --> 252         self._make_plot()
#     253         self._add_table()
#     254         self._make_legend()
#
# /Users/ice/PycharmProjects/sklearn-study/venv/lib/python3.6/site-packages/pandas/plotting/_core.py in _make_plot(self)
#     975                              stacking_id=stacking_id,
#     976                              is_errorbar=is_errorbar,
# --> 977                              **kwds)
#     978             self._add_legend_handle(newlines[0], label, index=i)
#     979
#
# /Users/ice/PycharmProjects/sklearn-study/venv/lib/python3.6/site-packages/pandas/plotting/_core.py in _ts_plot(cls, ax, x, data, style, **kwds)
#    1016         lines = cls._plot(ax, data.index, data.values, style=style, **kwds)
#    1017         # set date formatter, locators and rescale limits
# -> 1018         format_dateaxis(ax, ax.freq, data.index)
#    1019         return lines
#    1020
#
# /Users/ice/PycharmProjects/sklearn-study/venv/lib/python3.6/site-packages/pandas/plotting/_timeseries.py in format_dateaxis(subplot, freq, index)
#     342         raise TypeError('index type not supported')
#     343
# --> 344     pylab.draw_if_interactive()
#
# /Users/ice/PycharmProjects/sklearn-study/venv/lib/python3.6/site-packages/IPython/utils/decorators.py in wrapper(*args, **kw)
#      41     def wrapper(*args,**kw):
#      42         wrapper.called = False
# ---> 43         out = func(*args,**kw)
#      44         wrapper.called = True
#      45         return out
#
# /Applications/PyCharm.app/Contents/helpers/pycharm_matplotlib_backend/backend_interagg.py in draw_if_interactive()
#      37         figManager = Gcf.get_active()
#      38         if figManager is not None:
# ---> 39             figManager.canvas.show()
#      40
#      41
#
# AttributeError: 'FigureCanvasAgg' object has no attribute 'show'

# %%
df = pd.DataFrame({'class':['a','a','b','b','a','a','b','c','c'],'score':[3,5,6,7,8,9,10,11,14]})
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>a</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>a</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>b</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>b</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>a</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>a</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>b</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>c</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>c</td>
#       <td>14</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.sort_values(['class','score'],ascending=[1,0],inplace=True)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
#       <td>a</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>a</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>a</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>a</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>b</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>b</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>b</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>c</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>c</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
grouped = df.groupby(['class']).head(2)
grouped
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
#       <td>a</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>a</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>b</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>b</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>c</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>c</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>
